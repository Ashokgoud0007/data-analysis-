# %% [markdown]
# # covid -19 data analysis using python

# %%
# importing the necessary libruaries 
import pandas as pd 
data=pd.read_csv(r"https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv")

# %%
data.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %% [markdown]
# #### find the number of rows and columns

# %%
data.shape
# Out:
# (57394, 49)

# %% [markdown]
# #### Data types of columns

# %%
data.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %% [markdown]
# #### Info & describe of data in dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
# count of unique values in location column

unique_values  = data['location'].nunique()

# %%
unique_values
# Out:
# 216

# %%
#continent has maximum frequency using values


continent_counts = data['continent'].value_counts()

# %%
continent_counts
# Out:
# continent
# Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# Name: count, dtype: int64

# %%
max_continent = continent_counts.idxmax()
max_frequency = continent_counts.max()

# %%
print(max_continent,"and ",max_frequency)
# Out:
# Europe and  14828

# %%
# Calculate maximum and mean values
max_value = data['total_cases'].max()
mean_value = data['total_cases'].mean()

print(f"Maximum total cases: {max_value}")
print(f"Mean total cases: {mean_value}")
# Out:
# Maximum total cases: 55154651.0
# Mean total cases: 167797.3688753302

# %%
# Calculate quartiles
quartiles = data['total_deaths'].quantile([0.25, 0.50, 0.75])
print(f"25th percentile (Q1): {quartiles[0.25]}")
print(f"50th percentile (Q2/Median): {quartiles[0.50]}")
print(f"75th percentile (Q3): {quartiles[0.75]}")
# Out:
# 25th percentile (Q1): 13.0
# 50th percentile (Q2/Median): 84.0
# 75th percentile (Q3): 727.0

# %%
# Group by continent and find the maximum HDI
max_hdi_by_continent = data.groupby('continent')['human_development_index'].max()

# Find the continent with the maximum HDI
max_continent = max_hdi_by_continent.idxmax()
max_hdi_value = max_hdi_by_continent.max()

print(f"The continent with the maximum Human Development Index is {max_continent} with an HDI of {max_hdi_value}.")
# Out:
# The continent with the maximum Human Development Index is Europe with an HDI of 0.953.

# %%
# Group by continent and find the minimum GDP per capita
min_gdp_by_continent = data.groupby('continent')['gdp_per_capita'].min()

# Find the continent with the minimum GDP per capita
min_continent = min_gdp_by_continent.idxmin()
min_gdp_value = min_gdp_by_continent.min()

print(f"The continent with the minimum GDP per capita is {min_continent} with a GDP per capita of {min_gdp_value}.")
# Out:
# The continent with the minimum GDP per capita is Africa with a GDP per capita of 661.24.

# %%
# Filter the DataFrame to keep only the specified columns
columns_to_keep = ['continent', 'location', 'date', 'total_cases', 'total_deaths', 'gdp_per_capita', 'human_development_index']
df_filtered = data[columns_to_keep]
df_filtered
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
# Remove duplicate observations
data_dp = data.drop_duplicates()

# Display the DataFrame after removing duplicates
data_dp
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# Finding missing values in all columns
missing_values = data.isnull().sum()

# Display the count of missing values for each column
print(missing_values)
# Out:
# iso_code                                323
# continent                               646
# location                                  0
# date                                      0
# total_cases                            3636
# new_cases                               929
# new_cases_smoothed                     1742
# total_deaths                          13026
# new_deaths                              929
# new_deaths_smoothed                    1742
# total_cases_per_million                3923
# new_cases_per_million                   993
# new_cases_smoothed_per_million         1807
# total_deaths_per_million              13298
# new_deaths_per_million                  993
# new_deaths_smoothed_per_million        1807
# reproduction_rate                     19698
# icu_patients                          52904
# icu_patients_per_million              52904
# hosp_patients                         52389
# hosp_patients_per_million             52389
# ...

# %%
# Remove all observations where the 'continent' column value is missing
data = data.dropna(subset=['continent'])

# Display the updated DataFrame
data
# Out:
#       iso_code continent     location      date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia  Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...          ...       ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  13/11/20       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  14/11/20       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  15/11/20       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  16/11/20       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# Fill all missing values with 0
data = data.fillna(0)

# Display the updated DataFrame
data
# Out:
#       iso_code continent     location      date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  31/12/19          0.0        0.0
# 1          AFG      Asia  Afghanistan  01/01/20          0.0        0.0
# 2          AFG      Asia  Afghanistan  02/01/20          0.0        0.0
# 3          AFG      Asia  Afghanistan  03/01/20          0.0        0.0
# 4          AFG      Asia  Afghanistan  04/01/20          0.0        0.0
# ...        ...       ...          ...       ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  13/11/20       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  14/11/20       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  15/11/20       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  16/11/20       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# Convert the 'date' column to datetime format
data['date'] = pd.to_datetime(data['date'], errors='coerce')

# Display the updated DataFrame
data
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2212\2034271311.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['date'] = pd.to_datetime(data['date'], errors='coerce')
#       iso_code continent     location       date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan 2019-12-31          0.0        0.0
# 1          AFG      Asia  Afghanistan 2020-01-01          0.0        0.0
# 2          AFG      Asia  Afghanistan 2020-02-01          0.0        0.0
# 3          AFG      Asia  Afghanistan 2020-03-01          0.0        0.0
# 4          AFG      Asia  Afghanistan 2020-04-01          0.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe 2020-11-13       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe 2020-11-14       8765.0       69.0
# ...

# %%
# Create a new column 'month' by extracting the month from the 'date' column
data['month'] = data['date'].dt.month

# Display the updated DataFrame
data
# Out:
#       iso_code continent     location       date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan 2019-12-31          0.0        0.0
# 1          AFG      Asia  Afghanistan 2020-01-01          0.0        0.0
# 2          AFG      Asia  Afghanistan 2020-02-01          0.0        0.0
# 3          AFG      Asia  Afghanistan 2020-03-01          0.0        0.0
# 4          AFG      Asia  Afghanistan 2020-04-01          0.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe 2020-11-13       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe 2020-11-14       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe 2020-11-15       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe 2020-11-16       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe 2020-11-17       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# Group by 'continent' and find the max value in all columns
max_values = data.groupby('continent').max().reset_index()

# Display the result
max_values
# Out:
#        continent iso_code                      location       date  \
# 0         Africa      ZWE                      Zimbabwe 2020-12-11
# 1           Asia      YEM                         Yemen 2020-12-11
# 2         Europe      VAT                       Vatican 2020-12-11
# 3  North America      VIR  United States Virgin Islands 2020-12-11
# 4        Oceania      WLF             Wallis and Futuna 2020-12-11
# 5  South America      VEN                     Venezuela 2020-12-11
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...

# %%
# Group by 'continent' and find the max value in all columns
df_groupby = data.groupby('continent').max().reset_index()

# Display the new DataFrame
df_groupby
# Out:
#        continent iso_code                      location       date  \
# 0         Africa      ZWE                      Zimbabwe 2020-12-11
# 1           Asia      YEM                         Yemen 2020-12-11
# 2         Europe      VAT                       Vatican 2020-12-11
# 3  North America      VIR  United States Virgin Islands 2020-12-11
# 4        Oceania      WLF             Wallis and Futuna 2020-12-11
# 5  South America      VEN                     Venezuela 2020-12-11
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...

# %%
# Create a new feature 'total_deaths_to_total_cases'
df_groupby['total_deaths_to_total_cases'] = df_groupby['total_deaths'] / df_groupby['total_cases']

# Display the updated DataFrame
df_groupby
# Out:
#        continent iso_code                      location       date  \
# 0         Africa      ZWE                      Zimbabwe 2020-12-11
# 1           Asia      YEM                         Yemen 2020-12-11
# 2         Europe      VAT                       Vatican 2020-12-11
# 3  North America      VIR  United States Virgin Islands 2020-12-11
# 4        Oceania      WLF             Wallis and Futuna 2020-12-11
# 5  South America      VEN                     Venezuela 2020-12-11
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...

# %%
# Plotting the histogram of 'gdp_per_capita'

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.histplot(data['gdp_per_capita'], bins=30, kde=True)  # kde=True adds a kernel density estimate
plt.title('Distribution of GDP per Capita')
plt.xlabel('GDP per Capita')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plotting the scatter plot of 'total_cases' vs 'gdp_per_capita'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='total_cases', y='gdp_per_capita', hue='continent', style='continent', s=100)

# Adding titles and labels
plt.title('Scatter Plot of Total Cases vs GDP per Capita')
plt.xlabel('total cases ')
plt.ylabel('GDP per capita')
plt.grid(True)

# Show the plot
plt.show()

# %%
# Plotting the pairplot
#sns.pairplot(df_groupby, hue='continent', markers=["o", "s", "D", "X"])

# Show the plot
#plt.show()

# %%
 # Plotting the bar plot using catplot from df_groupby data
sns.catplot(data=df_groupby, x='continent', y='total_cases', kind='bar', height=6, aspect=2.5)

# Adding titles and labels
plt.title('Total Cases by Continent')
plt.xlabel('Continent')
plt.ylabel('Total Cases')

# Show the plot
plt.show()

# %%
# Plotting the bar plot using catplot from original data
sns.catplot(data=data, x='continent', y='total_cases', kind='bar', height=6, aspect=2.5)

# Adding titles and labels
plt.title('Total Cases by Continent')
plt.xlabel('Continent')
plt.ylabel('Total Cases')

# Show the plot
plt.show()

# %%
# Specify the file path where you want to save the CSV
file_path = 'df_groupby.csv'  # Change this to your desired file path

# Save the DataFrame to a CSV file
df_groupby.to_csv(file_path, index=False)

print(f"DataFrame saved to {file_path}")
# Out:
# DataFrame saved to df_groupby.csv

# %%
# importing saved new groupby dataset
data1=pd.read_csv("df_groupby.csv")
data1
# Out:
#        continent iso_code                      location        date  \
# 0         Africa      ZWE                      Zimbabwe  2020-12-11
# 1           Asia      YEM                         Yemen  2020-12-11
# 2         Europe      VAT                       Vatican  2020-12-11
# 3  North America      VIR  United States Virgin Islands  2020-12-11
# 4        Oceania      WLF             Wallis and Futuna  2020-12-11
# 5  South America      VEN                     Venezuela  2020-12-11
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...
